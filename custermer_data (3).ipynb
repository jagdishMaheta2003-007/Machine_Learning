# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/customer_data.csv')
df
# Out:
#        Age  Gender  AnnualIncome  NumberOfPurchases ProductCategory  \
# 0     40.0  Female   66120.26794                8.0     Electronics
# 1     20.0  Female   23579.77358                4.0      Home Goods
# 2     27.0  Female  127821.30640               11.0      Home Goods
# 3     24.0  Female  137798.62310               19.0          Beauty
# 4     31.0  Female   99300.96422               19.0        Clothing
# ...    ...     ...           ...                ...             ...
# 1495  39.0  Female   65048.14183               13.0     Electronics
# 1496  67.0  Female   28775.33107               18.0      Home Goods
# 1497  40.0  Female   57363.24754                7.0          Sports
# 1498  63.0    Male  134021.77550               16.0      Home Goods
# 1499  50.0    Male   52625.66597               13.0     Electronics
#
#       TimeSpentOnWebsite LoyaltyProgram  DiscountsAvailed PurchaseStatus
# 0              30.568601             No                 5            Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1495 non-null   float64
#  1   Gender              1500 non-null   object
#  2   AnnualIncome        1495 non-null   float64
#  3   NumberOfPurchases   1495 non-null   float64
#  4   ProductCategory     1500 non-null   object
#  5   TimeSpentOnWebsite  1495 non-null   float64
#  6   LoyaltyProgram      1500 non-null   object
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 105.6+ KB

# %%
df.describe()
# Out:
#                Age   AnnualIncome  NumberOfPurchases  TimeSpentOnWebsite  \
# count  1495.000000    1495.000000        1495.000000         1495.000000
# mean     44.309699   84250.575795          10.418729           30.496235
# std      15.543686   37667.360933           5.892038           16.973948
# min      18.000000   20001.512520           0.000000            1.037023
# 25%      31.000000   52847.266355           5.000000           16.227049
# 50%      45.000000   83842.444820          11.000000           30.957377
# 75%      57.000000  117167.772900          15.000000           44.373182
# max      70.000000  149785.176500          20.000000           59.991105
#
#        DiscountsAvailed
# count       1500.000000
# mean           2.555333
# std            1.705152
# min            0.000000
# 25%            1.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
df.isnull().sum()
# Out:
# Age                   5
# Gender                0
# AnnualIncome          5
# NumberOfPurchases     5
# ProductCategory       0
# TimeSpentOnWebsite    5
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['AnnualIncome']=df['AnnualIncome'].fillna(df['AnnualIncome'].median())

# %%
df['NumberOfPurchases']=df['NumberOfPurchases'].fillna(df['NumberOfPurchases'].mean())

# %%
np.mean(abs(df['AnnualIncome']-df['AnnualIncome'].mean()))
# Out:
# 32378.53890949144

# %%
df['TimeSpentOnWebsite']=df['TimeSpentOnWebsite'].fillna(df['TimeSpentOnWebsite'].mean())

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
df['ProductCategory'].value_counts()
# Out:
# ProductCategory
# Clothing       331
# Sports         321
# Electronics    289
# Beauty         286
# Home Goods     273
# Name: count, dtype: int64

# %%
sns.set(style="whitegrid")

# %%
sns.pairplot(df,hue='PurchaseStatus')

# %%
df.hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
df
# Out:
#        Age  Gender  AnnualIncome  NumberOfPurchases ProductCategory  \
# 0     40.0  Female   66120.26794                8.0     Electronics
# 1     20.0  Female   23579.77358                4.0      Home Goods
# 2     27.0  Female  127821.30640               11.0      Home Goods
# 3     24.0  Female  137798.62310               19.0          Beauty
# 4     31.0  Female   99300.96422               19.0        Clothing
# ...    ...     ...           ...                ...             ...
# 1495  39.0  Female   65048.14183               13.0     Electronics
# 1496  67.0  Female   28775.33107               18.0      Home Goods
# 1497  40.0  Female   57363.24754                7.0          Sports
# 1498  63.0    Male  134021.77550               16.0      Home Goods
# 1499  50.0    Male   52625.66597               13.0     Electronics
#
#       TimeSpentOnWebsite LoyaltyProgram  DiscountsAvailed PurchaseStatus
# 0              30.568601             No                 5            Yes
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
df['Gender']=enc.fit_transform(df['Gender'])
df['ProductCategory']=enc.fit_transform(df['ProductCategory'])
df['PurchaseStatus']=enc.fit_transform(df['PurchaseStatus'])

# %%
df.head()
# Out:
#     Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0  40.0       0   66120.26794                8.0                2
# 1  20.0       0   23579.77358                4.0                3
# 2  27.0       0  127821.30640               11.0                3
# 3  24.0       0  137798.62310               19.0                0
# 4  31.0       0   99300.96422               19.0                1
#
#    TimeSpentOnWebsite LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601             No                 5               1
# 1           38.240097             No                 5               0
# 2           31.633212            Yes                 0               1
# 3           46.167059             No                 4               1
# 4           19.823592             No                 0               1

# %%
df['LoyaltyProgram']=enc.fit_transform(df['LoyaltyProgram'])

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min=MinMaxScaler()

# %%
scaled_df = pd.DataFrame(min.fit_transform(df), columns=df.columns)
scaled_df
# Out:
#            Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0     0.423077     0.0      0.355351               0.40             0.50
# 1     0.038462     0.0      0.027571               0.20             0.75
# 2     0.173077     0.0      0.830766               0.55             0.75
# 3     0.115385     0.0      0.907642               0.95             0.00
# 4     0.250000     0.0      0.611013               0.95             0.25
# ...        ...     ...           ...                ...              ...
# 1388  0.403846     0.0      0.347090               0.65             0.50
# 1389  0.942308     0.0      0.067603               0.90             0.75
# 1390  0.423077     0.0      0.287877               0.35             1.00
# 1391  0.865385     1.0      0.878541               0.80             0.75
# 1392  0.615385     1.0      0.251373               0.65             0.50
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
x=df.drop('PurchaseStatus',axis=1)
y=df['PurchaseStatus']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
te=DecisionTreeClassifier()

# %%
te.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=te.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,mean_squared_error,confusion_matrix,classification_report,roc_curve

# %%
print('accuracy_score : ',accuracy_score(y_test,y_pred))
print('mean_squared_error : ',mean_squared_error(y_test,y_pred))
# Out:
# accuracy_score :  0.8637992831541219
# mean_squared_error :  0.13620071684587814

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[119,  17],
#        [ 21, 122]])

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       136
#            1       0.88      0.85      0.87       143
#
#     accuracy                           0.86       279
#    macro avg       0.86      0.86      0.86       279
# weighted avg       0.86      0.86      0.86       279

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred1=rf.predict(x_test)

# %%
print('accuracy_score : ',accuracy_score(y_test,y_pred1))
print('mean_squared_error : ',mean_squared_error(y_test,y_pred1))
# Out:
# accuracy_score :  0.9283154121863799
# mean_squared_error :  0.07168458781362007

# %%
confusion_matrix(y_test,y_pred1)
# Out:
# array([[127,   9],
#        [ 11, 132]])

# %%
sns.heatmap(confusion_matrix(y_test,y_pred1))
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93       136
#            1       0.94      0.92      0.93       143
#
#     accuracy                           0.93       279
#    macro avg       0.93      0.93      0.93       279
# weighted avg       0.93      0.93      0.93       279

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred)
fpr1,tpr1,threshold=roc_curve(y_test,y_pred1)

# %%
plt.plot(fpr,tpr,label='te')
plt.plot(fpr1,tpr1,label='rf')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.legend()
plt.show()

# %%
from sklearn.svm import SVC

# %%
sv=SVC()

# %%
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
from sklearn.ensemble import BaggingClassifier
bag_clf = BaggingClassifier((RandomForestClassifier()), bootstrap=True, n_jobs=-1, oob_score=True)
bag_clf.fit(x_train, y_train)
y_pred3 = bag_clf.predict(x_test)
accuracy_score(y_test, y_pred3)
# Out:
# 0.9247311827956989

# %%
print('accuracy_score : ',accuracy_score(y_test,y_pred3))
print('mean_squared_error : ',mean_squared_error(y_test,y_pred3))
# Out:
# accuracy_score :  0.9247311827956989
# mean_squared_error :  0.07526881720430108

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred1)
fpr1,tpr1,threshold=roc_curve(y_test,y_pred3)

# %%
plt.plot(fpr,tpr,label='rf')
plt.plot(fpr1,tpr1,label='bag')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.legend()
plt.show()

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_model=model.predict(x_test)

# %%
print('accuracy_score : ',accuracy_score(y_test,y_pred_model))
print('mean_squared_error : ',mean_squared_error(y_test,y_pred_model))
# Out:
# accuracy_score :  0.9139784946236559
# mean_squared_error :  0.08602150537634409

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred1)
fpr1,tpr1,threshold=roc_curve(y_test,y_pred3)
fpr2,tpr2,threshold=roc_curve(y_test,y_pred_model)

# %%
plt.plot(fpr,tpr,label='rf')
plt.plot(fpr1,tpr1,label='bag')
plt.plot(fpr2,tpr2,label='xgb')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_clf = AdaBoostClassifier(RandomForestClassifier())
ada_clf.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=RandomForestClassifier())

# %%
y_pred_ada=ada_clf.predict(x_test)

# %%
print('accuracy_score : ',accuracy_score(y_test,y_pred_ada))
print('mean_squared_error : ',mean_squared_error(y_test,y_pred_ada))
# Out:
# accuracy_score :  0.921146953405018
# mean_squared_error :  0.07885304659498207

# %%
fpr4,tpr4,threshold=roc_curve(y_test,y_pred_ada)

# %%
plt.plot(fpr,tpr,label='rf')
plt.plot(fpr1,tpr1,label='bag')
plt.plot(fpr2,tpr2,label='xgb')
plt.plot(fpr4,tpr4,label='ada')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.legend()
plt.show()
