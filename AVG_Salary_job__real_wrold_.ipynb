# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/Average_Salary_by_Job_Classification.csv')
data
# Out:
#                          Position Title  Position Class Code Grade  \
# 0         Information Technology Expert                  550    32
# 1                 Accountant/Auditor II                  210    21
# 2                  Veterinary Assistant               206513    15
# 3                           Police Aide                 3506    15
# 4       ERP Functional Business Analyst               100546    30
# ..                                  ...                  ...   ...
# 316  Correctional Supervisor - Sergeant                 3234    C6
# 317                      Police Captain                 3063    A3
# 318                  Deputy Sheriff III                 3529    G4
# 319                         Manager III                  112    M3
# 320          Correctional Specialist IV                 3247    25
#
#     Average of Base Salary  Number of Employees
# 0              $146,925.34                    9
# 1               $82,742.44                    2
# ...

# %%
data.isnull().sum()
# Out:
# Position Title            0
# Position Class Code       0
# Grade                     0
# Average of Base Salary    0
# Number of Employees       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Position Title          321 non-null    object
#  1   Position Class Code     321 non-null    int64
#  2   Grade                   321 non-null    object
#  3   Average of Base Salary  321 non-null    object
#  4   Number of Employees     321 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 12.7+ KB

# %%
data['Average of Base Salary'] = data['Average of Base Salary'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
data
# Out:
#                          Position Title  Position Class Code Grade  \
# 0         Information Technology Expert                  550    32
# 1                 Accountant/Auditor II                  210    21
# 2                  Veterinary Assistant               206513    15
# 3                           Police Aide                 3506    15
# 4       ERP Functional Business Analyst               100546    30
# ..                                  ...                  ...   ...
# 316  Correctional Supervisor - Sergeant                 3234    C6
# 317                      Police Captain                 3063    A3
# 318                  Deputy Sheriff III                 3529    G4
# 319                         Manager III                  112    M3
# 320          Correctional Specialist IV                 3247    25
#
#      Average of Base Salary  Number of Employees
# 0                 146925.34                    9
# 1                  82742.44                    2
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Average of Base Salary'], bins=30, kde=True)
plt.title('Distribution of Average Salaries')
plt.xlabel('Average Salary')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(50,50))
sns.barplot(x='Average of Base Salary', y='Position Title', data=data)
plt.title('Salary Distribution by Job Title')
plt.xlabel('Average Salary')
plt.ylabel('Job Title')
plt.show()

# %%
data.head()
# Out:
#                     Position Title  Position Class Code Grade  \
# 0    Information Technology Expert                  550    32
# 1            Accountant/Auditor II                  210    21
# 2             Veterinary Assistant               206513    15
# 3                      Police Aide                 3506    15
# 4  ERP Functional Business Analyst               100546    30
#
#    Average of Base Salary  Number of Employees
# 0               146925.34                    9
# 1                82742.44                    2
# 2                45925.44                    2
# 3                58628.63                   15
# 4               133797.25                    3

# %%
top_paying_positions = data.sort_values(by='Average of Base Salary', ascending=False)[['Position Title','Average of Base Salary']].head(10)
top_paying_positions
# Out:
#                              Position Title  Average of Base Salary
# 278          Medical Doctor Psychiatrist IV               223953.00
# 155         Medical Doctor Psychiatrist III               203593.00
# 9                                 Manager I               182281.86
# 176  Information Technology Project Manager               182075.00
# 131               Senior Investment Officer               171350.49
# 212              Fire/Rescue Division Chief               168617.00
# 220                      Chief Veterinarian               162707.55
# 28                               Manager II               160257.48
# 258            Enterprise Technology Expert               159475.00
# 284          Chief Deputy Sheriff (Colonel)               159332.00

# %%
plt.figure(figsize=(5,8))
sns.barplot(x='Average of Base Salary', y='Position Title', data=top_paying_positions)
plt.title('Salary Distribution by Job Title')
plt.xlabel('Average Salary')
plt.ylabel('Job Title')
plt.show()

# %%
lowest_paying_positions=data.sort_values(by='Average of Base Salary', ascending=True)[['Position Title','Average of Base Salary']].head(10)
lowest_paying_positions
# Out:
#                            Position Title  Average of Base Salary
# 285                    Printer Apprentice                34147.77
# 260                       Messenger-Clerk                39366.25
# 315                   Supply Technician I                39379.32
# 180                          Office Clerk                41633.64
# 219                        Transit Aide I                42216.82
# 185   Information Technology Technician I                43178.13
# 148              Public Service Worker II                43945.42
# 267  Truck Driver Helper/Warehouse Worker                44057.14
# 187                       Revenue Counter                45331.49
# 2                    Veterinary Assistant                45925.44

# %%
plt.figure(figsize=(5,8))
sns.barplot(x='Average of Base Salary', y='Position Title', data=lowest_paying_positions)
plt.title('Salary Distribution by Job Title')
plt.xlabel('Average Salary')
plt.ylabel('Job Title')
plt.show()

# %%
data.head()
# Out:
#                     Position Title  Position Class Code Grade  \
# 0    Information Technology Expert                  550    32
# 1            Accountant/Auditor II                  210    21
# 2             Veterinary Assistant               206513    15
# 3                      Police Aide                 3506    15
# 4  ERP Functional Business Analyst               100546    30
#
#    Average of Base Salary  Number of Employees
# 0               146925.34                    9
# 1                82742.44                    2
# 2                45925.44                    2
# 3                58628.63                   15
# 4               133797.25                    3

# %%
data.groupby('Position Title')['Average of Base Salary'].sum()
# Out:
# Position Title
# Abandoned Vehicle Code Enforcement Specialist     58358.79
# Accountant/Auditor I                              67827.56
# Accountant/Auditor II                             82742.44
# Accountant/Auditor III                            97574.06
# Accountant/Auditor Supervisor                    112381.66
#                                                    ...
# Welder                                            78902.00
# Work Force Leader I                               58004.32
# Work Force Leader II                              72440.30
# Work Force Leader III                             58960.47
# Work Force Leader IV                              85688.31
# Name: Average of Base Salary, Length: 321, dtype: float64

# %%
data.groupby(['Position Title','Number of Employees'])['Average of Base Salary'].sum()
# Out:
# Position Title                                 Number of Employees
# Abandoned Vehicle Code Enforcement Specialist  4                       58358.79
# Accountant/Auditor I                           2                       67827.56
# Accountant/Auditor II                          2                       82742.44
# Accountant/Auditor III                         26                      97574.06
# Accountant/Auditor Supervisor                  9                      112381.66
#                                                                         ...
# Welder                                         3                       78902.00
# Work Force Leader I                            2                       58004.32
# Work Force Leader II                           26                      72440.30
# Work Force Leader III                          1                       58960.47
# Work Force Leader IV                           9                       85688.31
# ...

# %%
plt.figure(figsize=(10, 6))
employee_distribution = data[['Position Title', 'Number of Employees']].sort_values(by='Number of Employees', ascending=False)
sns.barplot(x='Number of Employees', y='Position Title', data=employee_distribution.head(10))
plt.title('Top 10 Job Titles by Number of Employees')
plt.xlabel('Number of Employees')
plt.ylabel('Position Title')
plt.show()

# %%
# Correlation Analysis
correlation = data[['Average of Base Salary', 'Number of Employees']].corr()

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
# Insights and Recommendations
print("\nTop Paying Positions:\n", top_paying_positions)
print("\nLowest Paying Positions:\n", lowest_paying_positions)

print("\nCorrelation between Average Salary and Number of Employees:", correlation)
# Out:
# Top Paying Positions:
#                               Position Title  Average of Base Salary
# 278          Medical Doctor Psychiatrist IV               223953.00
# 155         Medical Doctor Psychiatrist III               203593.00
# 9                                 Manager I               182281.86
# 176  Information Technology Project Manager               182075.00
# 131               Senior Investment Officer               171350.49
# 212              Fire/Rescue Division Chief               168617.00
# 220                      Chief Veterinarian               162707.55
# 28                               Manager II               160257.48
# 258            Enterprise Technology Expert               159475.00
# 284          Chief Deputy Sheriff (Colonel)               159332.00
#
# Lowest Paying Positions:
#                             Position Title  Average of Base Salary
# 285                    Printer Apprentice                34147.77
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data['Position Title']=enc.fit_transform(data['Position Title'])

# %%
 data['Grade']=enc.fit_transform(data['Grade'])

# %%
data
# Out:
#      Position Title  Position Class Code  Grade  Average of Base Salary  \
# 0               125                  550     22               146925.34
# 1                 2                  210     11                82742.44
# 2               310               206513      5                45925.44
# 3               202                 3506      5                58628.63
# 4                71               100546     20               133797.25
# ..              ...                  ...    ...                     ...
# 316              51                 3234     42                94434.43
# 317             203                 3063     33               156780.64
# 318              64                 3529     50                83677.86
# 319             174                  112     53               132146.03
# 320              49                 3247     15               105117.90
#
#      Number of Employees
# 0                      9
# 1                      2
# ...

# %%
num=data.select_dtypes(include=np.number).columns
num
# Out:
# Index(['Position Title', 'Position Class Code', 'Grade',
#        'Average of Base Salary', 'Number of Employees'],
#       dtype='object')

# %%
df=data.copy()

# %%
for column in num:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min=MinMaxScaler()

# %%
df = pd.DataFrame(min.fit_transform(data),columns=data.columns )
df
# Out:
#      Position Title  Position Class Code     Grade  Average of Base Salary  \
# 0          0.390625             0.002132  0.372881                0.594175
# 1          0.006250             0.000484  0.186441                0.256024
# 2          0.968750             1.000000  0.084746                0.062051
# 3          0.631250             0.016453  0.084746                0.128979
# 4          0.221875             0.486601  0.338983                0.525009
# ..              ...                  ...       ...                     ...
# 316        0.159375             0.015135  0.711864                0.317624
# 317        0.634375             0.014307  0.559322                0.646098
# 318        0.200000             0.016565  0.847458                0.260952
# 319        0.543750             0.000010  0.898305                0.516310
# 320        0.153125             0.015198  0.254237                0.373910
#
#      Number of Employees
# 0               0.009877
# ...

# %%
df.head()
# Out:
#    Position Title  Position Class Code     Grade  Average of Base Salary  \
# 0        0.390625             0.002132  0.372881                0.594175
# 1        0.006250             0.000484  0.186441                0.256024
# 2        0.968750             1.000000  0.084746                0.062051
# 3        0.631250             0.016453  0.084746                0.128979
# 4        0.221875             0.486601  0.338983                0.525009
#
#    Number of Employees
# 0             0.009877
# 1             0.001235
# 2             0.001235
# 3             0.017284
# 4             0.002469

# %%
plt.figure(figsize=(8,10))
sns.boxplot(x='Number of Employees', y='Average of Base Salary', data=data) # Removed extra space/tab from y column name
plt.title("Price vs. Number of Stops")
# Out:
# Text(0.5, 1.0, 'Price vs. Number of Stops')

# %%
sns.boxplot(x='Number of Employees', y='Average of Base Salary', data=df) # Removed extra space/tab from y column name
plt.show()

# %%
x = df.drop(['Average of Base Salary'], axis=1)
y = df['Average of Base Salary']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Mean Squared Error: 0.00
# R-squared: 0.82

# %%
r2
# Out:
# 0.8183431311146807

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.3717278592423936
# 0.3904563122425455

# %%
from sklearn.metrics import mean_squared_error,r2_score
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.3904563122425455
# 0.011778388695656094

# %%
from sklearn.tree import DecisionTreeRegressor
te=DecisionTreeRegressor()
te.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
print(te.score(x_train,y_train))
print(te.score(x_test,y_test))
# Out:
# 1.0
# 0.5139255011907221

# %%
y_pred=te.predict(x_test)

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.5139255011907221
# 0.009392557903577245

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=60,max_depth=8,random_state=42)
rf.fit(x_train, y_train)
y_pred_rf=rf.predict(x_test)
print(te.score(x_train,y_train))
print(te.score(x_test,y_test))
# Out:
# 1.0
# 0.5139255011907221

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.5139255011907221
# 0.009392557903577245

# %%
import xgboost as xgb
xg=xgb.XGBRegressor()
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
print(xg.score(x_train,y_train))
print(xg.score(x_test,y_test))
# Out:
# 0.9998958163349198
# 0.7584761609355218

# %%
y_pred_xg=xg.predict(x_test)
print(r2_score(y_test,y_pred_xg))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.7584761609355218
# 0.009392557903577245

# %%
from sklearn.ensemble import AdaBoostRegressor
model=AdaBoostRegressor()
model.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.8472210247525174
# 0.755397838542008

# %%
y_pred=model.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.755397838542008
# 0.004726518199293132
